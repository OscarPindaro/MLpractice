# %% [markdown]
# # Kernel methods

# %% [markdown]
# ## Classification

# %%
import numpy as np
import matplotlib.pyplot as plt
import random as rand
import math

# %%
Npoints = 500
class1 = np.zeros((Npoints, 3))
for row in class1:
    radius = rand.random() - 0.5
    theta = rand.random()*2*math.pi
    x = radius*math.cos(theta)
    y = radius*math.sin(theta)
    row[0] =x
    row[1] = y

class1[:,2] = np.ones(Npoints)*-1

class2 = np.zeros((Npoints, 3))

for row in class2:
    theta = rand.random()*2*math.pi
    radius = rand.uniform(0.6, 1)
    x = radius*math.cos(theta)
    y = radius*math.sin(theta)
    row[0] = x
    row[1] = y
    
class2[:, 2] = np.ones(Npoints)    

dataset = np.append(class1, class2).reshape(Npoints*2,3)
np.random.shuffle(dataset)

# %%
plt.plot(class1[:, 0], class1[:,1], 'o')
plt.plot(class2[:, 0], class2[:,1], 'o')
plt.show()

# %%
def kernel(x1, x2):
    return x1.transpose()@x2

# %%
def calculateK(trainSet, kernel):
    inputs = trainSet[:, :-1]
    K = np.zeros((inputs.shape[0], inputs.shape[0]))
    for i in range(inputs.shape[0]):
        for j in range(inputs.shape[0]):
            K[i,j] = kernel(inputs[i], inputs[j])
    return K        

def calculateFunction(x, invK, trainSet, kernel):
    inputs = trainSet[:, :-1]
    outputs = trainSet[:, -1]
    k = np.zeros(inputs.shape[0])
    for i in range(inputs.shape[0]):
        k[i] = kernel(x, inputs[i])
    
    return k.transpose()@invK@outputs

# %%
trainset = dataset.copy()
prediction = np.zeros(trainset.shape[0])

K = calculateK(trainset, kernel)
invK = np.linalg.inv(K)
inputs = trainset[:, :-1]
for i in range(trainset.shape[0]):
    if calculateFunction(inputs[i], invK, trainset, kernel) > 0:
        prediction[i] = 1
    else:
        prediction[i] = -1

# %%
predDat = np.ones((trainset.shape[0], trainset.shape[1]+1))
predDat[:, :-1] = trainset 
predDat[:, -1] = prediction

class1 = predDat[predDat[:,2] == -1][:,:3]
missClass1 = predDat[predDat[:,2] != predDat[:,3]]
missClass1 = missClass1[missClass1[:,2]==-1]

class2 = predDat[predDat[:,2] == 1][:,:3]
missClass2 = predDat[predDat[:,2] != predDat[:,3]]
missClass2 = missClass2[missClass2[:,2]==1]

# %%
fig, ax = plt.subplots()
plt.xlim(np.min(trainset[:,0]-0.2), np.max(trainset[:,0])+0.2)
plt.ylim(np.min(trainset[:,1])-0.2, np.max(trainset[:,1])+0.2)
plt.plot(class1[:,0], class1[:,1], "o")
plt.plot(class2[:,0], class2[:,1], "o")
plt.plot(missClass1[:,0], missClass1[:,1], "o", color = "green")
plt.plot(missClass2[:,0], missClass2[:,1], "o", color = "red")
plt.show()

# %%
datSize = trainset.shape[0]
miss = missClass1.shape[0]+missClass2.shape[0]
print("Total points: {}. Misclassified points: {}.\nMissclassification rate: {}".format(datSize, miss, miss/datSize))
# Out:
# Total points: 1000. Misclassified points: 482.
# Missclassification rate: 0.482

# %% [markdown]
# Now lets draw the decision surface

# %%
x = np.linspace(-1, +1, 1000)
y = np.linspace(-1, +1, 1000)
out = np.zeros((x.shape[0], y.shape[0]))

for i in range(x.shape[0]):
    for j in range(y.shape[0]):
        if(i+j%10== 0):
            print("Epoch {}, {} {}".format(i+j, i, j))
        vectorInput = np.array([x[i], y[j]])    
        out[i,j] = calculateFunction(vectorInput, invK, trainset, kernel)
# Out:
# Epoch 0, 0 0
# Epoch 10, 0 10
# Epoch 20, 0 20
# Epoch 30, 0 30
# Epoch 40, 0 40
# Epoch 50, 0 50
# Epoch 60, 0 60
# Epoch 70, 0 70
# Epoch 80, 0 80
# Epoch 90, 0 90
# Epoch 100, 0 100
# Epoch 110, 0 110
# Epoch 120, 0 120
# Epoch 130, 0 130
# Epoch 140, 0 140
# Epoch 150, 0 150
# Epoch 160, 0 160
# Epoch 170, 0 170
# Epoch 180, 0 180
# Epoch 190, 0 190
# Epoch 200, 0 200
# Epoch 210, 0 210
# Epoch 220, 0 220
# Epoch 230, 0 230
# Epoch 240, 0 240
# Epoch 250, 0 250
# Epoch 260, 0 260
# Epoch 270, 0 270
# Epoch 280, 0 280
# Epoch 290, 0 290
# Epoch 300, 0 300
# Epoch 310, 0 310
# Epoch 320, 0 320
# Epoch 330, 0 330
# Epoch 340, 0 340
# Epoch 350, 0 350
# Epoch 360, 0 360
# Epoch 370, 0 370
# Epoch 380, 0 380
# Epoch 390, 0 390
# Epoch 400, 0 400
# Epoch 410, 0 410
# Epoch 420, 0 420
# Epoch 430, 0 430
# Epoch 440, 0 440
# Epoch 450, 0 450
# Epoch 460, 0 460
# Epoch 470, 0 470
# Epoch 480, 0 480
# Epoch 490, 0 490
# Epoch 500, 0 500
# Epoch 510, 0 510
# Epoch 520, 0 520
# Epoch 530, 0 530
# Epoch 540, 0 540
# Epoch 550, 0 550
# Epoch 560, 0 560
# Epoch 570, 0 570
# Epoch 580, 0 580
# Epoch 590, 0 590
# Epoch 600, 0 600
# Epoch 610, 0 610
# Epoch 620, 0 620
# Epoch 630, 0 630
# Epoch 640, 0 640
# Epoch 650, 0 650
# Epoch 660, 0 660
# Epoch 670, 0 670
# Epoch 680, 0 680
# Epoch 690, 0 690
# Epoch 700, 0 700
# Epoch 710, 0 710
# Epoch 720, 0 720
# Epoch 730, 0 730
# Epoch 740, 0 740
# Epoch 750, 0 750
# Epoch 760, 0 760
# Epoch 770, 0 770
# Epoch 780, 0 780
# Epoch 790, 0 790
# Epoch 800, 0 800
# Epoch 810, 0 810
# Epoch 820, 0 820
# Epoch 830, 0 830
# Epoch 840, 0 840
# Epoch 850, 0 850
# Epoch 860, 0 860
# Epoch 870, 0 870
# Epoch 880, 0 880
# Epoch 890, 0 890
# Epoch 900, 0 900
# Epoch 910, 0 910
# Epoch 920, 0 920
# Epoch 930, 0 930
# Epoch 940, 0 940
# Epoch 950, 0 950
# Epoch 960, 0 960
# Epoch 970, 0 970
# Epoch 980, 0 980
# Epoch 990, 0 990
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-32b5d646f25b> in <module>
#       8             print("Epoch {}, {} {}".format(i+j, i, j))
#       9         vectorInput = np.array([x[i], y[j]])
# ---> 10         out[i,j] = calculateFunction(vectorInput, invK, trainset, kernel)
#
# <ipython-input-5-439d48fa7630> in calculateFunction(x, invK, trainSet, kernel)
#      14         k[i] = kernel(x, inputs[i])
#      15
# ---> 16     return k.transpose()@invK@outputs
#
# KeyboardInterrupt:

# %%
realOut = np.where(np.isclose(out, 3), out, -1)
dsx = []
dsy = []
for i in range(realOut.shape[0]):
    for j in range(realOut.shape[1]):
        if(realOut[i,j] != -1):
            dsx.append(x[i])
            dsy.append(y[j])

# %%
plt.plot(class1[:, 0], class1[:,1], 'o')
plt.plot(class2[:, 0], class2[:,1], 'o')
plt.plot(dsx, dsy, '.')
plt.show()
